# %%
import pandas as pd
import glob
import numpy as np

# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#2 Equally distributed (PISGD)
x_nodes = []
with open("original/changing_ni_ml100/recall2.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_2 = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_2.append(sum(sma) / float(n))

# %%
#2 Equally distributed (PISGD) with SWUBSC
x_nodes = []
with open("SlidingWindowUBSC_ni_ml100/ForgettingOnlyItemsFromUserItemRatingHistory_window=1000/recall2.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_2_w = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_2_w.append(sum(sma) / float(n))

# %%
#2 Equally distributed (PISGD) with SWUBSC
x_nodes = []
with open("LFU/old_structure/100k/recall2.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_2_lfu = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_2_lfu.append(sum(sma) / float(n))

# %%
#2 Equally distributed (PISGD) with SWUBSC
x_nodes = []
with open("LRU/old_structure/100k/recall2.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_2_lru = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_2_lru.append(sum(sma) / float(n))

# %%
#4 Equally distributed (PISGD)
x_nodes = []
with open("original/changing_ni_ml100/recall4.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_4 = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_4.append(sum(sma) / float(n))

# %%
#4 Equally distributed (PISGD) with SWUBSC
x_nodes = []
with open("SlidingWindowUBSC_ni_ml100/ForgettingOnlyItemsFromUserItemRatingHistory_window=1000/recall4.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_4_w = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_4_w.append(sum(sma) / float(n))

# %%
#2 Equally distributed (PISGD) with SWUBSC
x_nodes = []
with open("LFU/old_structure/100k/recall4.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_4_lfu = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_4_lfu.append(sum(sma) / float(n))

# %%
#2 Equally distributed (PISGD) with SWUBSC
x_nodes = []
with open("LRU/old_structure/100k/recall4.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_4_lru = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_4_lru.append(sum(sma) / float(n))

# %%
#6 Equally distributed (PISGD)
x_nodes = []
with open("original/changing_ni_ml100/recall6.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_6 = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_6.append(sum(sma) / float(n))

# %%
#6 Equally distributed (PISGD) with SWUBSC
x_nodes = []
with open("SlidingWindowUBSC_ni_ml100/ForgettingOnlyItemsFromUserItemRatingHistory_window=1000/recall6.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_6_w = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_6_w.append(sum(sma) / float(n))

# %%
#2 Equally distributed (PISGD) with SWUBSC
x_nodes = []
with open("LFU/old_structure/100k/recall6.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_6_lfu = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_6_lfu.append(sum(sma) / float(n))

# %%
#2 Equally distributed (PISGD) with SWUBSC
x_nodes = []
with open("LRU/old_structure/100k/recall6.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_6_lru = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_6_lru.append(sum(sma) / float(n))

# %%
#2 Equally distributed (PISGD) with SWUBSC
x_nodes = []
with open("LRU/old_structure/100k/recall2.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_2_lru = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_2_lru.append(sum(sma) / float(n))

# %%
#8 Equally distributed (PISGD)
x_nodes = []
with open("original/changing_ni_ml100/recall8.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_7 = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_7.append(sum(sma) / float(n))

# %%
#8 Equally distributed (PISGD)
x_nodes = []
with open("SlidingWindowUBSC_ni_ml100/ForgettingOnlyItemsFromUserItemRatingHistory_window=1000/recall8.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_7_w = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_7_w.append(sum(sma) / float(n))

# %%
#2 Equally distributed (PISGD) with SWUBSC
x_nodes = []
with open("LFU/old_structure/100k/recall8.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_8_lfu = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_8_lfu.append(sum(sma) / float(n))

# %%
#2 Equally distributed (PISGD) with SWUBSC
x_nodes = []
with open("LRU/old_structure/100k/recall8.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_8_lru = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_8_lru.append(sum(sma) / float(n))

# %%
#10 Equally distributed (PISGD)
x_nodes = []
with open("original/changing_ni_ml100/recall10.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_10 = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_10.append(sum(sma) / float(n))

# %%
#10 Equally distributed (PISGD)
x_nodes = []
with open("SlidingWindowUBSC_ni_ml100/ForgettingOnlyItemsFromUserItemRatingHistory_window=1000/recall10.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_10_w = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_10_w.append(sum(sma) / float(n))

# %%
#2 Equally distributed (PISGD) with SWUBSC
x_nodes = []
with open("LFU/old_structure/100k/recall10.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_10_lfu = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_10_lfu.append(sum(sma) / float(n))

# %%
#2 Equally distributed (PISGD) with SWUBSC
x_nodes = []
with open("LRU/old_structure/100k/recall10.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_10_lru = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_10_lru.append(sum(sma) / float(n))

# %%
#1 centrAL
x_nodes = []
with open("original/changing_ni_ml100/recall1.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_1 = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_1.append(sum(sma) / float(n))

# %%
#1 centrAL with UBSWC
x_nodes = []
with open("SlidingWindowUBSC_ni_ml100/ForgettingOnlyItemsFromUserItemRatingHistory_window=1000/recall1.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_1_w = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_1_w.append(sum(sma) / float(n))

# %%
#2 Equally distributed (PISGD) with SWUBSC
x_nodes = []
with open("LFU/old_structure/100k/recall1.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_1_lfu = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_1_lfu.append(sum(sma) / float(n))

# %%
#2 Equally distributed (PISGD) with SWUBSC
x_nodes = []
with open("LRU/old_structure/100k/recall1.txt", 'r') as f:
    lines = f.readlines()
for l in lines:
    x_nodes.append(int(l.strip()))
recall_avgs_1_lru = []
sma = []
for ct in x_nodes:
    sma.append(ct)
    n = len(sma)
    if n > 5000:
        del sma[0]
        n -= 1
        recall_avgs_1_lru.append(sum(sma) / float(n))

# %%
fig, ax = plt.subplots()
#ax.plot(empty,ax=ax)
#empty.plot(ax=ax)
ax.plot(recall_avgs_1,label = 'centralized', color = 'blue')
ax.plot(recall_avgs_2,label = r'$n_i=2$', color = 'blue')
ax.plot(recall_avgs_4,label = r'$n_i=4$', color = 'blue')
ax.plot(recall_avgs_6,label = r'$n_i=6$', color = 'blue')
ax.plot(recall_avgs_7,label = r'$n_i=8$', color = 'blue')
ax.plot(recall_avgs_10,label = r'$n_i=10$', color = 'blue')


ax.plot(recall_avgs_1_w,label = 'centralized FT', color = 'red')
ax.plot(recall_avgs_2_w,label = r'$n_i=2$,FT', color = 'red')
ax.plot(recall_avgs_4_w,label = r'$n_i=4$,FT', color = 'red')
ax.plot(recall_avgs_6_w,label = r'$n_i=6$,FT', color = 'red')
ax.plot(recall_avgs_7_w,label = r'$n_i=8$,FT', color = 'red')
ax.plot(recall_avgs_10_w,label = r'$n_i=10$,FT', color = 'red')



ax.set_xlabel('index')
ax.set_ylabel('recall@10')
ax.grid(True)
ax.set_title("SMA Recall for CF using similarity metric with and without sliding window forgetting technique window size 1000")
#ax.set_xticks([0, 50000, 100000, 150000])
#ax.set_yticks([0.00, 0.05, 0.10, 0.15])
fig.set_size_inches((15,5))
#fig.patch.set_alpha(0.5)
handles, labels = ax.get_legend_handles_labels()
ax.legend(labels)

# %%
len(recall_avgs_1)
# Out:
# 215296

# %%
len(recall_avgs_20)
# Out:
# 130889

# %%
len(recall_avgs_5)
# Out:
# 193657

# %%
fig, ax = plt.subplots()
#ax.plot(empty,ax=ax)
#empty.plot(ax=ax)
ax.plot(recall_avgs_1,label = 'centralized', color = 'blue')
ax.plot(recall_avgs_2,label = r'$n_i=2$', color = 'blue')
ax.plot(recall_avgs_4,label = r'$n_i=4$', color = 'blue')
ax.plot(recall_avgs_6,label = r'$n_i=6$', color = 'blue')
ax.plot(recall_avgs_7,label = r'$n_i=8$', color = 'blue')
ax.plot(recall_avgs_10,label = r'$n_i=10$', color = 'blue')


ax.plot(recall_avgs_1_w,label = 'centralized FT', color = 'red')
ax.plot(recall_avgs_2_w,label = r'$n_i=2$,FT', color = 'red')
ax.plot(recall_avgs_4_w,label = r'$n_i=4$,FT', color = 'red')
ax.plot(recall_avgs_6_w,label = r'$n_i=6$,FT', color = 'red')
ax.plot(recall_avgs_7_w,label = r'$n_i=8$,FT', color = 'red')
ax.plot(recall_avgs_10_w,label = r'$n_i=10$,FT', color = 'red')


ax.plot(recall_avgs_1_lfu,label = 'centralized FT', color = 'yellow')
ax.plot(recall_avgs_2_lfu,label = r'$n_i=2$,FT', color = 'yellow')
ax.plot(recall_avgs_4_lfu,label = r'$n_i=4$,FT', color = 'yellow')
ax.plot(recall_avgs_6_lfu,label = r'$n_i=6$,FT', color = 'yellow')
ax.plot(recall_avgs_8_lfu,label = r'$n_i=8$,FT', color = 'yellow')
ax.plot(recall_avgs_10_lfu,label = r'$n_i=10$,FT', color = 'yellow')


ax.plot(recall_avgs_1_lru,label = 'centralized FT', color = 'orange')
ax.plot(recall_avgs_2_lru,label = r'$n_i=2$,FT', color = 'orange')
ax.plot(recall_avgs_4_lru,label = r'$n_i=4$,FT', color = 'orange')
ax.plot(recall_avgs_6_lru,label = r'$n_i=6$,FT', color = 'orange')
ax.plot(recall_avgs_8_lru,label = r'$n_i=8$,FT', color = 'orange')
ax.plot(recall_avgs_10_lru,label = r'$n_i=10$,FT', color = 'orange')




ax.set_xlabel('index')
ax.set_ylabel('recall@10')
ax.grid(True)
ax.set_title("SMA Recall for CF using similarity metric with and without forgetting technique")
#ax.set_xticks([0, 50000, 100000, 150000])
#ax.set_yticks([0.00, 0.05, 0.10, 0.15])
fig.set_size_inches((15,5))
#fig.patch.set_alpha(0.5)
handles, labels = ax.get_legend_handles_labels()

import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

blue_patch = mpatches.Patch(color='blue', label='without Forgetting')
red_patch = mpatches.Patch(color='red', label='Sliding Window')
yellow_patch = mpatches.Patch(color='yellow', label='LFU')
orange_patch = mpatches.Patch(color='orange', label='LRU')
plt.legend(handles=[blue_patch,red_patch,yellow_patch,orange_patch])

#plt.show()

# %%
df = pd.DataFrame(["3m:50s","1m:28s","38s","23s","17s","16s"])
df.columns = ["time_without_Forgetting"]

# %%
df.index = ["recall1","recall2","recall4","recall6","recall8","recall10"]

# %%
df
# Out:
#          time_without_Forgetting
# recall1                   3m:50s
# recall2                   1m:28s
# recall4                      38s
# recall6                      23s
# recall8                      17s
# recall10                     16s

# %%
df["time_LFU_forgetting"] = ["3m:44s","1m:20s","34s","21s","16s","12s"]

# %%
df
# Out:
#          time_without_Forgetting time_LFU_forgetting
# recall1                   3m:50s              3m:44s
# recall2                   1m:28s              1m:20s
# recall4                      38s                 34s
# recall6                      23s                 21s
# recall8                      17s                 16s
# recall10                     16s                 12s

# %%
df["time_LRU_forgetting"] = ["2m:20s","1m","28","17s","12s","10s"]

# %%
df
# Out:
#          time_without_Forgetting time_LFU_forgetting time_LRU_forgetting
# recall1                   3m:50s              3m:44s              2m:20s
# recall2                   1m:28s              1m:20s                  1m
# recall4                      38s                 34s                  28
# recall6                      23s                 21s                 17s
# recall8                      17s                 16s                 12s
# recall10                     16s                 12s                 10s
